# %%
#Alcune prove per capire il progetto https://www.kaggle.com/c/DontGetKicked/data
print("Hello")
# Out:
# Hello

# %%
#import vari
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv("training.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-572924c7ee9f> in <module>()
# ----> 1 df = pd.read_csv("training.csv")
#
# ...

# %%
df.head()

# %%
df.tail()
# Out:
#        RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge       Make  \
# 72978  73010         1  12/2/2009   ADESA     2001           8    MERCURY
# 72979  73011         0  12/2/2009   ADESA     2007           2  CHEVROLET
# 72980  73012         0  12/2/2009   ADESA     2005           4       JEEP
# 72981  73013         0  12/2/2009   ADESA     2006           3  CHEVROLET
# 72982  73014         0  12/2/2009   ADESA     2006           3      MAZDA
#
#                       Model Trim         SubModel      ...       \
# 72978                 SABLE   GS      4D SEDAN GS      ...
# 72979             MALIBU 4C   LS      4D SEDAN LS      ...
# 72980  GRAND CHEROKEE 2WD V  Lar  4D WAGON LAREDO      ...
# 72981                IMPALA   LS      4D SEDAN LS      ...
# 72982                MAZDA6    s       4D SEDAN S      ...
#
#       MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT  \
# 72978                       4836.0                     5937.0        NaN
# ...

# %%
df.dtypes
# Out:
# RefId                                  int64
# IsBadBuy                               int64
# PurchDate                             object
# Auction                               object
# VehYear                                int64
# VehicleAge                             int64
# Make                                  object
# Model                                 object
# Trim                                  object
# SubModel                              object
# Color                                 object
# Transmission                          object
# WheelTypeID                          float64
# WheelType                             object
# VehOdo                                 int64
# Nationality                           object
# Size                                  object
# TopThreeAmericanName                  object
# MMRAcquisitionAuctionAveragePrice    float64
# MMRAcquisitionAuctionCleanPrice      float64
# MMRAcquisitionRetailAveragePrice     float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72983 entries, 0 to 72982
# Data columns (total 34 columns):
# RefId                                72983 non-null int64
# IsBadBuy                             72983 non-null int64
# PurchDate                            72983 non-null object
# Auction                              72983 non-null object
# VehYear                              72983 non-null int64
# VehicleAge                           72983 non-null int64
# Make                                 72983 non-null object
# Model                                72983 non-null object
# Trim                                 70623 non-null object
# SubModel                             72975 non-null object
# Color                                72975 non-null object
# Transmission                         72974 non-null object
# WheelTypeID                          69814 non-null float64
# WheelType                            69809 non-null object
# ...

# %%
df.describe()
# Out:
# /Users/AlessandroMacagno/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               RefId      IsBadBuy       VehYear    VehicleAge   WheelTypeID  \
# count  72983.000000  72983.000000  72983.000000  72983.000000  69814.000000
# mean   36511.428497      0.122988   2005.343052      4.176644      1.494299
# std    21077.241302      0.328425      1.731252      1.712210      0.521290
# min        1.000000      0.000000   2001.000000      0.000000      0.000000
# 25%    18257.500000      0.000000   2004.000000      3.000000           NaN
# 50%    36514.000000      0.000000   2005.000000      4.000000           NaN
# 75%    54764.500000      0.000000   2007.000000      5.000000           NaN
# max    73014.000000      1.000000   2010.000000      9.000000      3.000000
#
#               VehOdo  MMRAcquisitionAuctionAveragePrice  \
# count   72983.000000                       72965.000000
# ...

# %%
df.VehicleAge.corr(df['IsBadBuy'])
# Out:
# 0.16716408469719568

# %%
df.corr()
# Out:
#                                       RefId  IsBadBuy   VehYear  VehicleAge  \
# RefId                              1.000000  0.023973  0.010580   -0.025404
# IsBadBuy                           0.023973  1.000000 -0.158886    0.167164
# VehYear                            0.010580 -0.158886  1.000000   -0.957957
# VehicleAge                        -0.025404  0.167164 -0.957957    1.000000
# WheelTypeID                        0.013110 -0.044620  0.259660   -0.250801
# VehOdo                            -0.026553  0.082560 -0.283719    0.319794
# MMRAcquisitionAuctionAveragePrice -0.011568 -0.109252  0.581146   -0.565690
# MMRAcquisitionAuctionCleanPrice   -0.015704 -0.102954  0.532927   -0.518810
# MMRAcquisitionRetailAveragePrice  -0.032208 -0.087418  0.581191   -0.460854
# MMRAcquisitonRetailCleanPrice     -0.034324 -0.083665  0.539230   -0.426382
# MMRCurrentAuctionAveragePrice     -0.008742 -0.109112  0.590820   -0.575607
# ...

# %%
pd.scatter_matrix(df[['IsBadBuy', 'VehYear']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14633cef0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14651a278>]], dtype=object)

# %%
# Set up a grid of plots
fig = plt.figure(figsize=(10, 10)) 
fig_dims = (3, 2)

# Plot death and survival counts
plt.subplot2grid(fig_dims, (0, 0))
df['IsBadBuy'].value_counts().plot(kind='bar', title='IsBadBuy')

# %%
pclass_xt = pd.crosstab(df['VehYear'], df['IsBadBuy'])
pclass_xt
# Out:
# IsBadBuy      0     1
# VehYear
# 2001       1055   426
# 2002       2587   818
# 2003       5017  1210
# 2004       8620  1587
# 2005      13457  2032
# 2006      15443  1600
# 2007      10535   888
# 2008       6500   385
# 2009        792    30
# 2010          1     0

# %%
# Normalize the cross tab to sum to 1:
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct
# Out:
# IsBadBuy         0         1
# VehYear
# 2001      0.712357  0.287643
# 2002      0.759765  0.240235
# 2003      0.805685  0.194315
# 2004      0.844518  0.155482
# 2005      0.868810  0.131190
# 2006      0.906120  0.093880
# 2007      0.922262  0.077738
# 2008      0.944081  0.055919
# 2009      0.963504  0.036496
# 2010      1.000000  0.000000

# %%
pclass_xt_pct.plot(kind='bar', stacked=True, title='IsBadBuy per Year')
plt.xlabel('Year')
plt.ylabel('IsBadBuy')
